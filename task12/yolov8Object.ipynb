# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.5/719.5 kB 15.4 MB/s eta 0:00:00

# %%
# !yolo detect predict model=yolov8m.pt source="/content/motorbikes.mp4"
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 327MB/s]
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m summary (fused): 218 layers, 25886080 parameters, 0 gradients, 78.9 GFLOPs
#
# video 1/1 (1/686) /content/motorbikes.mp4: 352x640 3 persons, 8 cars, 3 motorcycles, 1 bus, 1 truck, 155.0ms
# video 1/1 (2/686) /content/motorbikes.mp4: 352x640 3 persons, 7 cars, 3 motorcycles, 1 bus, 1 truck, 25.2ms
# video 1/1 (3/686) /content/motorbikes.mp4: 352x640 4 persons, 7 cars, 3 motorcycles, 1 bus, 1 truck, 25.2ms
# video 1/1 (4/686) /content/motorbikes.mp4: 352x640 3 persons, 7 cars, 3 motorcycles, 1 bus, 1 truck, 25.3ms
# video 1/1 (5/686) /content/motorbikes.mp4: 352x640 3 persons, 7 cars, 3 motorcycles, 1 bus, 1 truck, 26.3ms
# video 1/1 (6/686) /content/motorbikes.mp4: 352x640 4 persons, 7 cars, 3 motorcycles, 1 bus, 1 truck, 25.3ms
# video 1/1 (7/686) /content/motorbikes.mp4: 352x640 3 persons, 7 cars, 2 motorcycles, 1 bus, 1 truck, 25.3ms
# ...

# %%
# !ffmpeg -i {"/content/runs/detect/predict/motorbikes.avi"} -vcodec libx264 {"final.mp4"}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
